# %%
import numpy as np
import pandas as pd

from pycoingecko import CoinGeckoAPI

from bs4 import BeautifulSoup as bts
import requests
import pandas as pd
import numpy as np

# %% [markdown]
# ### Coin Gecko API

# %%
cg = CoinGeckoAPI()

# %%
# Test
cg.get_coin_ohlc_by_id(id="ethereum", vs_currency="usd", days="30")
# Out:
# [[1715587200000, 2888.53, 2929.66, 2872.77, 2929.13],
#  [1715601600000, 2953.43, 2984.55, 2953.43, 2964.74],
#  [1715616000000, 2965.72, 2980.62, 2949.41, 2965.85],
#  [1715630400000, 2961.44, 2973.79, 2932.52, 2955.83],
#  [1715644800000, 2954.26, 2957.82, 2938.76, 2948.3],
#  [1715659200000, 2949.04, 2957.4, 2939.81, 2939.81],
#  [1715673600000, 2940.6, 2948.58, 2889.62, 2918.57],
#  [1715688000000, 2918.68, 2918.68, 2899.9, 2906.3],
#  [1715702400000, 2906.33, 2917.86, 2875.33, 2901.6],
#  [1715716800000, 2897.13, 2897.13, 2867.87, 2895.68],
#  [1715731200000, 2891.68, 2897.97, 2879.07, 2881.8],
#  [1715745600000, 2880.78, 2898.47, 2866.02, 2898.47],
#  [1715760000000, 2899.93, 2916.69, 2898.18, 2916.69],
#  [1715774400000, 2915.63, 2928.78, 2888.34, 2901.14],
#  [1715788800000, 2897.1, 2990.87, 2897.1, 2980.6],
#  [1715803200000, 2978.04, 3025.14, 2973.53, 3016.68],
#  [1715817600000, 3024.76, 3040.59, 3014.39, 3035.76],
#  [1715832000000, 3036.4, 3038.46, 3002.3, 3018.54],
# ...

# %%
cg.get_coins_markets(vs_currency="usd")[50]
# Out:
# {'id': 'floki',
#  'symbol': 'floki',
#  'name': 'FLOKI',
#  'image': 'https://coin-images.coingecko.com/coins/images/16746/large/PNG_image.png?1696516318',
#  'current_price': 0.00023814,
#  'market_cap': 2308573223,
#  'market_cap_rank': 51,
#  'fully_diluted_valuation': 2381687309,
#  'total_volume': 487659120,
#  'high_24h': 0.00025137,
#  'low_24h': 0.00022091,
#  'price_change_24h': -7.529612654177e-06,
#  'price_change_percentage_24h': -3.06497,
#  'market_cap_change_24h': -86012133.23272038,
#  'market_cap_change_percentage_24h': -3.59194,
#  'circulating_supply': 9693015598472.0,
#  'total_supply': 10000000000000.0,
#  'max_supply': 10000000000000.0,
#  'ath': 0.00034495,
#  'ath_change_percentage': -30.95153,
#  'ath_date': '2024-06-05T07:25:59.137Z',
#  'atl': 8.428e-08,
#  'atl_change_percentage': 282508.96631,
#  'atl_date': '2021-07-06T01:11:20.438Z',
#  'roi': None,
#  'last_updated': '2024-06-12T07:45:38.599Z'}

# %%
cg.get_coins_markets(vs_currency="usd")[1]["name"]
# Out:
# 'Ethereum'

# %%
cg.get_coins_markets(vs_currency="usd")[1]["market_cap"]
# Out:
# 422938957193

# %% [markdown]
# Only for a very limited number of coins.

# %% [markdown]
# ### Scraping

# %% [markdown]
# Try this: https://github.com/HayrullahKaraman/Machine_Learning_Project/blob/main/BeatifulSoup_Coingecko.ipynb?source=post_page-----a8405cfffec4--------------------------------

# %%
url = 'https://www.coingecko.com/'
result = requests.get(url, headers={"User-Agent":"Mozilla/5.0"})
soup = bts(result.text, 'html.parser')

# %%
<span data-price-target="price" data-price-btc="19711212.0" data-prev-price="1329460834535.22">$1,329,460,834,535</span>

# %%
<td data-sort="1329670626038.5547" data-view-component="true" class="tw-text-gray-900 dark:tw-text-moon-50 tw-px-1 tw-py-2.5 2lg:tw-p-2.5 tw-bg-inherit tw-text-end">
  <span data-price-target="price" data-price-btc="19711212.0" data-prev-price="1329460834535.22">$1,329,460,834,535</span>
</td>

# %%
<span data-price-target="price" data-price-btc="19711212.0" data-prev-price="1329460834535.22">$1,329,460,834,535</span>

# %%
soup.find('span', {'data-price-target': 'price'}).text
# Out:
# '$2,581,152,950,320'

# %%
soup.find('td', {'data-sort': True}).get('data-sort')
# Out:
# '67461.49928176602'

# %% [markdown]
# 10, 14, 18...

# %%
soup.findAll('span', {'data-price-target': 'price'})[18].text
# Out:
# '$112,528,170,286'

# %%
for a in soup.findAll('span', {'data-price-target': 'price'}):
    print(a.span.text.strip().replace('$',''))
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[44], line 2
#       1 for a in soup.findAll('span', {'data-price-target': 'price'}):
# ----> 2     print(a.span.text.strip().replace('$',''))
#
# AttributeError: 'NoneType' object has no attribute 'text'

# %%
#Test Connect
soup
# Out:
# <!DOCTYPE html>
#
# <html lang="en">
# <head>
# <meta charset="utf-8"/>
# <meta content="IE=edge" http-equiv="X-UA-Compatible"/>
# <meta content="width=device-width, initial-scale=1.0" name="viewport"/>
# <link href="/favicon.ico" rel="shortcut icon"/>
# <link href="/OpensearchDescription.xml" rel="search" type="application/opensearchdescription+xml">
# <title>Cryptocurrency Prices, Charts, and Crypto Market Cap | CoinGecko</title>
# <meta content="View top cryptocurrency prices live, crypto charts, market cap, and trading volume. Discover today’s new and trending coins, top crypto gainers and losers in the market." name="description">
# <!-- OptanonConsentNoticeStart -->
# <script charset="UTF-8" data-document-language="true" data-domain-script="49e8a847-f2c7-4b58-a340-caf0924064fe" defer="" src="https://cdn-apac.onetrust.com/scripttemplates/otSDKStub.js" type="text/javascript"></script>
# <script type="text/javascript">
#   const STRICT_COOKIE = "C0001";
# ...

# %%
soup.find("span",{"span":"class"}).text.replace('\n','')

# %%
soup.find("td",{"class":"data-coin-id='1364' data-price-btc"})
